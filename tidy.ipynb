# %%
import pandas as pd
import numpy as np

# %%
df_wine=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data',header=None)
df_wine.columns=['Class label', 'Alcohol','Malic acid', 'Ash','Alcalinity of ash', 'Magnesium','Total phenols', 'Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity', 'Hue','OD280/OD315 of diluted wines','Proline']
print('Class labels',np.unique(df_wine['Class label']))
df_wine.head()
# Out:
# Class labels [1 2 3]
#    Class label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0            1    14.23        1.71  2.43               15.6        127
# 1            1    13.20        1.78  2.14               11.2        100
# 2            1    13.16        2.36  2.67               18.6        101
# 3            1    14.37        1.95  2.50               16.8        113
# 4            1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# ...

# %%
x=pd.melt(df_wine,id_vars='Class label')
x.head()
# Out:
#    Class label variable  value
# 0            1  Alcohol  14.23
# 1            1  Alcohol  13.20
# 2            1  Alcohol  13.16
# 3            1  Alcohol  14.37
# 4            1  Alcohol  13.24

# %%
y=pd.melt(df_wine,id_vars=['Malic acid','Ash','Magnesium'],var_name='class label')
y.head()
# Out:
#    Malic acid   Ash  Magnesium  class label  value
# 0        1.71  2.43        127  Class label    1.0
# 1        1.78  2.14        100  Class label    1.0
# 2        2.36  2.67        101  Class label    1.0
# 3        1.95  2.50        113  Class label    1.0
# 4        2.59  2.87        118  Class label    1.0

# %%
df_wine.head()
# Out:
#    Class label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0            1    14.23        1.71  2.43               15.6        127
# 1            1    13.20        1.78  2.14               11.2        100
# 2            1    13.16        2.36  2.67               18.6        101
# 3            1    14.37        1.95  2.50               16.8        113
# 4            1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# ...

# %%
df=pd.read_csv('./Desktop/covid.csv',low_memory=False)
df
# Out:
#        Direction  Year        Date    Weekday Country Commodity  \
# 0        Exports  2015  01/01/2015   Thursday     All       All
# 1        Exports  2015  02/01/2015     Friday     All       All
# 2        Exports  2015  03/01/2015   Saturday     All       All
# 3        Exports  2015  04/01/2015     Sunday     All       All
# 4        Exports  2015  05/01/2015     Monday     All       All
# ...          ...   ...         ...        ...     ...       ...
# 99734  Reimports  2021  20/03/2021   Saturday     All       All
# 99735  Reimports  2021  21/03/2021     Sunday     All       All
# 99736  Reimports  2021  22/03/2021     Monday     All       All
# 99737  Reimports  2021  23/03/2021    Tuesday     All       All
# 99738  Reimports  2021  24/03/2021  Wednesday     All       All
#
#       Transport_Mode Measure      Value  Cumulative
# 0                All       $  104000000   104000000
# 1                All       $   96000000   200000000
# ...

# %%
long=pd.melt(df,id_vars=['Direction','Year','Value'])

# %%
long.head()
# Out:
#   Direction  Year      Value variable       value
# 0   Exports  2015  104000000     Date  01/01/2015
# 1   Exports  2015   96000000     Date  02/01/2015
# 2   Exports  2015   61000000     Date  03/01/2015
# 3   Exports  2015   74000000     Date  04/01/2015
# 4   Exports  2015  105000000     Date  05/01/2015

# %%
'Transport_Mode'.split('_')
# Out:
# ['Transport', 'Mode']

# %%
df['Value'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99734    False
# 99735    False
# 99736    False
# 99737    False
# 99738    False
# Name: Value, Length: 99739, dtype: bool

# %%
def detect(df):
    for col in df.columns:
        pct=np.mean(df[col].isnull())
        print('{} is missing {}%'.format(col,round(pct*100)))

# %%
detect(df)
# Out:
# Direction is missing 0.0%
# Year is missing 0.0%
# Date is missing 0.0%
# Weekday is missing 0.0%
# Country is missing 0.0%
# Commodity is missing 0.0%
# Transport_Mode is missing 0.0%
# Measure is missing 0.0%
# Value is missing 0.0%
# Cumulative is missing 0.0%

# %%
detect(df_wine)
# Out:
# Class label is missing 0.0%
# Alcohol is missing 0.0%
# Malic acid is missing 0.0%
# Ash is missing 0.0%
# Alcalinity of ash is missing 0.0%
# Magnesium is missing 0.0%
# Total phenols is missing 0.0%
# Flavanoids is missing 0.0%
# Nonflavanoid phenols is missing 0.0%
# Proanthocyanins is missing 0.0%
# Color intensity is missing 0.0%
# Hue is missing 0.0%
# OD280/OD315 of diluted wines is missing 0.0%
# Proline is missing 0.0%

# %%
df_2=pd.read_csv('./Desktop/data.csv',header=None)
df_2.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# ...

# %%
detect(df_2)
# Out:
# 0 is missing 0.0%
# 1 is missing 0.0%
# 2 is missing 0.0%
# 3 is missing 0.0%
# 4 is missing 0.0%
# 5 is missing 0.0%
# 6 is missing 0.0%
# 7 is missing 0.0%
# 8 is missing 0.0%
# 9 is missing 0.0%
# 10 is missing 0.0%
# 11 is missing 0.0%
# 12 is missing 0.0%
# 13 is missing 0.0%
# 14 is missing 0.0%
# 15 is missing 0.0%
# 16 is missing 0.0%
# 17 is missing 0.0%
# 18 is missing 0.0%
# 19 is missing 0.0%
# 20 is missing 0.0%
# 21 is missing 0.0%
# 22 is missing 0.0%
# 23 is missing 0.0%
# 24 is missing 0.0%
# 25 is missing 0.0%
# 26 is missing 0.0%
# 27 is missing 0.0%
# 28 is missing 0.0%
# 29 is missing 0.0%
# 30 is missing 0.0%
# 31 is missing 0.0%

# %%
df_house=pd.read_csv('./Desktop/property_data.csv',header=None)
detect(df_house)
# Out:
# 0 is missing 10.0%
# 1 is missing 20.0%
# 2 is missing 0.0%
# 3 is missing 10.0%
# 4 is missing 20.0%
# 5 is missing 10.0%
# 6 is missing 10.0%

# %%
df.columns
# Out:
# Index(['Direction', 'Year', 'Date', 'Weekday', 'Country', 'Commodity',
#        'Transport_Mode', 'Measure', 'Value', 'Cumulative'],
#       dtype='object')

# %%
alg=pd.read_csv('./Desktop/alg.csv',header=None)
alg.columns=['Time','Temperature','Frequency','Phase_Angle','Complex_Modulus','Elastic_Modulus','Viscous_Modulus','Complex_Viscosity','Shear_Stress','Strain','Normal_Force']
alg.head()
# Out:
#                         Time Temperature    Frequency Phase_Angle  \
# 0   Data Pt[1]          :;;3    854;37;1  00E+00;30;2    02E+01;1
# 1  Data Pt[2]          :;;12    852;37;1    00E+00;27         1;2
# 2  Data Pt[3]          :;;21    861;37;1    00E+00;24         6;2
# 3  Data Pt[4]          :;;30    859;37;1    00E+00;22         5;3
# 4  Data Pt[5]          :;;39    861;37;1    00E+00;20         6;3
#
#   Complex_Modulus Elastic_Modulus Viscous_Modulus Complex_Viscosity  \
# 0        75E+01;1        01E+01;3        22E+00;2          00E+00;1
# 1        34E+01;2        08E+01;1        06E+01;3          72E+00;2
# 2        69E+01;2        44E+01;1        12E+01;4          27E+00;2
# 3        07E+01;2        83E+01;1        17E+01;4          88E+00;2
# 4        48E+01;3        25E+01;1        22E+01;5          53E+00;2
#
#   Shear_Stress    Strain  Normal_Force
# 0     06E-01;0         4           NaN
# 1     00E+00;9  12E-02;0           3.0
# ...

# %%
detect(alg)
# Out:
# Time is missing 0.0%
# Temperature is missing 1.0%
# Frequency is missing 1.0%
# Phase_Angle is missing 1.0%
# Complex_Modulus is missing 1.0%
# Elastic_Modulus is missing 1.0%
# Viscous_Modulus is missing 1.0%
# Complex_Viscosity is missing 1.0%
# Shear_Stress is missing 1.0%
# Strain is missing 4.0%
# Normal_Force is missing 23.0%

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
cols=alg.columns
sns.heatmap(alg[cols].isnull())

# %%
median = alg['Normal_Force'].median()#compute the median normal force
alg['Normal_Force'].fillna(median, inplace=True)#fill the na with the median

# %%
alg.head()
# Out:
#                         Time Temperature    Frequency Phase_Angle  \
# 0   Data Pt[1]          :;;3    854;37;1  00E+00;30;2    02E+01;1
# 1  Data Pt[2]          :;;12    852;37;1    00E+00;27         1;2
# 2  Data Pt[3]          :;;21    861;37;1    00E+00;24         6;2
# 3  Data Pt[4]          :;;30    859;37;1    00E+00;22         5;3
# 4  Data Pt[5]          :;;39    861;37;1    00E+00;20         6;3
#
#   Complex_Modulus Elastic_Modulus Viscous_Modulus Complex_Viscosity  \
# 0        75E+01;1        01E+01;3        22E+00;2          00E+00;1
# 1        34E+01;2        08E+01;1        06E+01;3          72E+00;2
# 2        69E+01;2        44E+01;1        12E+01;4          27E+00;2
# 3        07E+01;2        83E+01;1        17E+01;4          88E+00;2
# 4        48E+01;3        25E+01;1        22E+01;5          53E+00;2
#
#   Shear_Stress    Strain  Normal_Force
# 0     06E-01;0         4           5.0
# 1     00E+00;9  12E-02;0           3.0
# ...

# %%
detect(alg)
# Out:
# Time is missing 0.0%
# Temperature is missing 1.0%
# Frequency is missing 1.0%
# Phase_Angle is missing 1.0%
# Complex_Modulus is missing 1.0%
# Elastic_Modulus is missing 1.0%
# Viscous_Modulus is missing 1.0%
# Complex_Viscosity is missing 1.0%
# Shear_Stress is missing 1.0%
# Strain is missing 4.0%
# Normal_Force is missing 0.0%

# %%
fre_split=alg['Frequency'].str.split('+')

# %%
fre_split.head()
# Out:
# 0    [00E, 00;30;2]
# 1      [00E, 00;27]
# 2      [00E, 00;24]
# 3      [00E, 00;22]
# 4      [00E, 00;20]
# Name: Frequency, dtype: object

# %%
type(fre_split)
# Out:
# pandas.core.series.Series

# %%
a=fre_split[0]
type(a)
# Out:
# list

# %%
x=alg.dropna(how='any')
x.head()
# Out:
#                         Time Temperature    Frequency Phase_Angle  \
# 0   Data Pt[1]          :;;3    854;37;1  00E+00;30;2    02E+01;1
# 1  Data Pt[2]          :;;12    852;37;1    00E+00;27         1;2
# 2  Data Pt[3]          :;;21    861;37;1    00E+00;24         6;2
# 3  Data Pt[4]          :;;30    859;37;1    00E+00;22         5;3
# 4  Data Pt[5]          :;;39    861;37;1    00E+00;20         6;3
#
#   Complex_Modulus Elastic_Modulus Viscous_Modulus Complex_Viscosity  \
# 0        75E+01;1        01E+01;3        22E+00;2          00E+00;1
# 1        34E+01;2        08E+01;1        06E+01;3          72E+00;2
# 2        69E+01;2        44E+01;1        12E+01;4          27E+00;2
# 3        07E+01;2        83E+01;1        17E+01;4          88E+00;2
# 4        48E+01;3        25E+01;1        22E+01;5          53E+00;2
#
#   Shear_Stress    Strain  Normal_Force
# 0     06E-01;0         4           5.0
# 1     00E+00;9  12E-02;0           3.0
# ...

# %%
alg.shape
# Out:
# (203, 11)

# %%
x.shape
# Out:
# (195, 11)

# %%
y=alg.dropna(how='all')

# %%
y.shape
# Out:
# (203, 11)

# %%
y.head()
# Out:
#                         Time Temperature    Frequency Phase_Angle  \
# 0   Data Pt[1]          :;;3    854;37;1  00E+00;30;2    02E+01;1
# 1  Data Pt[2]          :;;12    852;37;1    00E+00;27         1;2
# 2  Data Pt[3]          :;;21    861;37;1    00E+00;24         6;2
# 3  Data Pt[4]          :;;30    859;37;1    00E+00;22         5;3
# 4  Data Pt[5]          :;;39    861;37;1    00E+00;20         6;3
#
#   Complex_Modulus Elastic_Modulus Viscous_Modulus Complex_Viscosity  \
# 0        75E+01;1        01E+01;3        22E+00;2          00E+00;1
# 1        34E+01;2        08E+01;1        06E+01;3          72E+00;2
# 2        69E+01;2        44E+01;1        12E+01;4          27E+00;2
# 3        07E+01;2        83E+01;1        17E+01;4          88E+00;2
# 4        48E+01;3        25E+01;1        22E+01;5          53E+00;2
#
#   Shear_Stress    Strain  Normal_Force
# 0     06E-01;0         4           5.0
# 1     00E+00;9  12E-02;0           3.0
# ...
